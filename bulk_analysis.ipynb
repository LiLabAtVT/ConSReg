# %%
import pandas as pd
import os
import re

from ConSReg import ConSReg

# %% [markdown]
# File names of input data

# %%
# Dap-seq narrow peak files
dap_file_list = os.listdir("data/dap_seq_all_peaks/")
dap_file = [ "data/dap_seq_all_peaks/" + file for file in dap_file_list if re.match(".*narrowPeak",file) is not None]

# ATAC-seq peak file
atac_file = "data/atac_seq_all_merged.bed"

# Arabidopsis genome annotation file
gff_file = "data/TAIR10_GFF3_genes.gff"

# Differential contrast result generated by DESeq2
diff_file_list = os.listdir("data/diff_evalB/")
diff_file = [ "data/diff_evalB/" + file for file in diff_file_list if re.match(".*csv",file) is not None]

# %% [markdown]
# Create a ConSReg object for analysis

# %%
analysis = ConSReg()

# %% [markdown]
# Read and preprocess all data files

# %%
analysis.preprocess(dap_file = dap_file, diff_file = diff_file, atac_file = atac_file, gff_file=gff_file)
# Out:
# Merging DAP-seq peaks...
# /work/alexsong/tools/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Import genomic features from the file as a GRanges object ...
#   warnings.warn(x, RRuntimeWarning)
# /work/alexsong/tools/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: OK
#
#   warnings.warn(x, RRuntimeWarning)
# >> preparing features information...		 2018-10-17 09:55:57 PM
# >> identifying nearest features...		 2018-10-17 09:55:57 PM
# >> calculating distance from peak to TSS...	 2018-10-17 09:57:11 PM
# >> assigning genomic annotation...		 2018-10-17 09:57:11 PM
# >> assigning chromosome lengths			 2018-10-17 09:57:38 PM
# >> done...					 2018-10-17 09:57:38 PM
# Done
# Overlapping DAP-seq with ATAC-seq...
# Done
# Reading diff tables...
# Done
# /work/alexsong/tools/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Prepare the 'metadata' data frame ...
#   warnings.warn(x, RRuntimeWarning)
# /work/alexsong/tools/anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Make the TxDb object ...
#   warnings.warn(x, RRuntimeWarning)
# <ConSReg.ConSReg instance at 0x7f21269d1098>

# %%
analysis.gen_feature_mat()
# Out:
# Generating feature matrices...
# Done
# <ConSReg.ConSReg instance at 0x7f21269d1098>

# %% [markdown]
# Generate feature matrices for each differential contrast

# %% [markdown]
# Compute AUC-ROC and AUC-PRC from corss-validation (CV) using LRLASSO method. Mean and standard deviation of AUC-ROC and AUC-PRC were reporeted from five replicates of CV

# %%
analysis.eval_by_cv(ml_engine = 'lrlasso',rep = 5, n_jobs = 44)
# Out:
# Performing cross-validation for each feature matrix using lrlasso engine...
# [Parallel(n_jobs=44)]: Done   1 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=44)]: Done   2 out of  44 | elapsed:   10.2s remaining:  3.6min
# [Parallel(n_jobs=44)]: Done   5 out of  44 | elapsed:   14.3s remaining:  1.9min
# [Parallel(n_jobs=44)]: Done   8 out of  44 | elapsed:   15.3s remaining:  1.1min
# [Parallel(n_jobs=44)]: Done  11 out of  44 | elapsed:   18.6s remaining:   55.7s
# [Parallel(n_jobs=44)]: Done  14 out of  44 | elapsed:   19.4s remaining:   41.5s
# [Parallel(n_jobs=44)]: Done  17 out of  44 | elapsed:   20.6s remaining:   32.7s
# [Parallel(n_jobs=44)]: Done  20 out of  44 | elapsed:   23.9s remaining:   28.7s
# [Parallel(n_jobs=44)]: Done  23 out of  44 | elapsed:   27.3s remaining:   24.9s
# [Parallel(n_jobs=44)]: Done  26 out of  44 | elapsed:   35.3s remaining:   24.5s
# [Parallel(n_jobs=44)]: Done  29 out of  44 | elapsed:   44.7s remaining:   23.1s
# [Parallel(n_jobs=44)]: Done  32 out of  44 | elapsed:   47.1s remaining:   17.7s
# [Parallel(n_jobs=44)]: Done  35 out of  44 | elapsed:   50.3s remaining:   12.9s
# [Parallel(n_jobs=44)]: Done  38 out of  44 | elapsed:   55.3s remaining:    8.7s
# [Parallel(n_jobs=44)]: Done  41 out of  44 | elapsed:   58.7s remaining:    4.3s
# [Parallel(n_jobs=44)]: Done  44 out of  44 | elapsed:  1.0min remaining:    0.0s
# [Parallel(n_jobs=44)]: Done  44 out of  44 | elapsed:  1.0min finished
# Done
# <ConSReg.ConSReg instance at 0x7f21269d1098>

# %% [markdown]
# Check the CV results

# %%
analysis.auroc
# Out:
#                             diff_name  auroc_mean_UR  auroc_std_UR  \
# 0         GSE81202_13-GSE81202_11.csv       0.814116      0.011186
# 1           GSE72806_3-GSE72806_1.csv       0.816361      0.009980
# 2           GSE69510_2-GSE69510_1.csv       0.872991      0.016182
# 3   PRJEB10930_4_T-PRJEB10930_4_C.csv       0.845177      0.004400
# 4         GSE81202_18-GSE81202_16.csv       0.842078      0.015224
# 5           GSE67332_5-GSE67332_4.csv       0.813359      0.016495
# 6         GSE81202_17-GSE81202_15.csv       0.848836      0.007454
# 7           GSE80565_7-GSE80565_8.csv       0.841519      0.010085
# 8           GSE63406_5-GSE63406_3.csv       0.827257      0.006889
# 9          GSE80565_9-GSE80565_10.csv       0.835047      0.019036
# 10          GSE69077_2-GSE69077_1.csv       0.829737      0.007898
# 11    PRJNA324514_2-PRJNA324514_1.csv       0.874288      0.017845
# 12          GSE69077_3-GSE69077_2.csv       0.803055      0.007006
# 13          GSE67332_3-GSE67332_2.csv       0.843543      0.006236
# 14        GSE59699_11-GSE59699_12.csv       0.869720      0.008450
# 15         GSE81202_10-GSE81202_8.csv       0.876540      0.028309
# 16          GSE69510_4-GSE69510_3.csv       0.885964      0.011365
# 17  PRJNA324514_14-PRJNA324514_13.csv       0.859300      0.020161
# 18    PRJNA324514_6-PRJNA314076_1.csv       0.817254      0.008251
# 19          GSE63406_6-GSE63406_4.csv       0.828518      0.007690
# 20  PRJNA324514_12-PRJNA324514_11.csv       0.858480      0.012811
# 21   PRJNA324514_10-PRJNA324514_9.csv       0.856236      0.010215
# 22          GSE60865_3-GSE60865_2.csv       0.884179      0.016431
# 23          GSE63406_3-GSE63406_1.csv       0.867263      0.004692
# 24          GSE72806_4-GSE72806_1.csv       0.804246      0.008027
# 25  PRJEB10930_3_T-PRJEB10930_3_C.csv       0.852118      0.020719
# 26        GSE59699_17-GSE59699_18.csv       0.868425      0.015474
# 27        GSE80565_11-GSE80565_12.csv       0.849036      0.013075
# 28        GSE80565_13-GSE80565_14.csv       0.834324      0.024643
# 29        GSE59699_15-GSE59699_16.csv       0.874289      0.005880
# 30    PRJNA324514_1-PRJNA314076_1.csv       0.813495      0.009016
# 31    PRJNA324514_4-PRJNA324514_3.csv       0.852712      0.012319
# 32        GSE59699_14-GSE59699_13.csv       0.826264      0.005745
# 33          GSE67332_2-GSE67332_1.csv       0.796319      0.010103
# 34          GSE80565_5-GSE80565_6.csv       0.857947      0.016860
# 35          GSE67332_6-GSE67332_5.csv       0.802933      0.008840
# 36          GSE80565_3-GSE80565_4.csv       0.867589      0.014842
# 37   PRJNA324514_11-PRJNA314076_1.csv       0.826070      0.007945
# 38          GSE59699_3-GSE59699_4.csv       0.912083      0.016957
# 39        GSE81202_14-GSE81202_12.csv       0.860447      0.014602
# 40  PRJNA324514_15-PRJNA324514_14.csv       0.844802      0.016977
# 41          GSE60865_2-GSE60865_1.csv       0.897305      0.012204
# 42    PRJNA324514_3-PRJNA324514_2.csv       0.886638      0.017494
# 43          GSE59699_7-GSE59699_8.csv       0.866749      0.021288
#
#     auroc_mean_DR  auroc_std_DR
# 0        0.874437      0.005554
# 1        0.845932      0.006617
# 2        0.861803      0.016924
# 3        0.818052      0.014804
# 4        0.828709      0.007584
# 5        0.837403      0.010939
# 6        0.838216      0.005513
# 7        0.810898      0.026635
# 8        0.863418      0.002842
# 9        0.797814      0.025172
# 10       0.822237      0.007734
# 11       0.881640      0.010639
# 12       0.836033      0.007264
# 13       0.815237      0.010930
# 14       0.832062      0.008044
# 15       0.915873      0.011504
# 16       0.838450      0.010125
# 17       0.879423      0.023406
# 18       0.825973      0.004260
# 19       0.862370      0.007048
# 20       0.872027      0.004298
# 21       0.787343      0.017456
# 22       0.879506      0.006742
# 23       0.835533      0.016636
# 24       0.834847      0.016464
# 25       0.821785      0.019540
# 26       0.843800      0.012568
# 27       0.815687      0.027605
# 28       0.794815      0.018193
# 29       0.852867      0.007408
# 30       0.819929      0.013237
# 31       0.875439      0.024441
# 32       0.871073      0.006778
# 33       0.833613      0.005055
# 34       0.823188      0.025565
# 35       0.827383      0.008587
# 36       0.780587      0.025540
# 37       0.821136      0.006982
# 38       0.888599      0.015813
# 39       0.859498      0.006699
# 40       0.860107      0.015662
# 41       0.837939      0.010631
# 42       0.872025      0.008796
# 43       0.861957      0.017074

# %% [markdown]
# Generate importance score for each TF

# %%
analysis.compute_imp_score(n_resampling = 200, n_jobs = 44, verbose = True)
# Out:
# Performing stability selection and compute importance score for each TF...
# Done
# <ConSReg.ConSReg instance at 0x7f21269d1098>

# %% [markdown]
# Generate GRN for each differential contrast

# %%
analysis.gen_networks(imp_cutoff = 0.5, verbose = True)
# Out:
# <ConSReg.ConSReg instance at 0x7f21269d1098>

# %% [markdown]
# Save analysis result

# %%
# Cross-validation result
analysis.auroc.to_csv("results/bulk_analysis/auroc_result.csv")
analysis.auprc.to_csv("results/bulk_analysis/auprc_result.csv")

# Importance scores
analysis.imp_scores_UR.to_csv("results/bulk_analysis/imp_score_UR.csv")
analysis.imp_scores_DR.to_csv("results/bulk_analysis/imp_score_DR.csv")

# Networks were saved in the format of edge list
for diff_name, network in zip(analysis.diff_name_list, analysis.networks_UR):
    network.to_csv("results/bulk_analysis/{}_UR_network.csv".format(diff_name))
    
for diff_name, network in zip(analysis.diff_name_list, analysis.networks_DR):
    network.to_csv("results/bulk_analysis/{}_DR_network.csv".format(diff_name))
